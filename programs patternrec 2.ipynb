# %%
#question 1
def find_name_in_wordlist(wordlist, string):
    count = 0
    index_list = []
    
    for word in wordlist:
        if name in word:
            count += 1
            index_list.append(word.index(name) + 1)  # Adding 1 to convert to 1-based index
        else:
            index_list.append(0)
    
    return (count, index_list)

# Example usage:
wordlist = ["hello", "world", "hell", "heaven", "shell"]
string = "hell"
result = find_name_in_wordlist(wordlist, string)
print(result)
# Out:
# (3, [1, 0, 1, 0, 2])

# %%
#question 2

import pandas as pd

# Specify the file path'
file_path="cars_dataset.csv"


# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Data cleaning
# 1.Removing duplicates
df = df.drop_duplicates()


# 2.Dropping Null values
df = df.dropna()
miles_to_kilometers = 1.60934
gallon_to_liter = 3.78541


#Converting miles per gallon to kilometers per liter
df['mileage']=(df['mileage']*miles_to_kilometers / gallon_to_liter)


# Save the cleaned and updated DataFrame back to CSV
df.to_csv('new_auto.csv', index=False)# Group the DataFrame by 'company name' and calculate the total
company_cars_count=df.groupby('company_name')['company_name'].count()

# Print the total number of cars for each company
print("Total cars of all companies:")
print(company_cars_count)
company_average=df.groupby('company_name')['mileage'].mean()
print("Average mileage of all the companies:",company_average)
# Out:
# Total cars of all companies:
# company_name
# Chevrolet    24
# Ford         30
# Honda        19
# Toyota       27
# Name: company_name, dtype: int64
# Average mileage of all the companies: company_name
# Chevrolet    10.238857
# Ford          9.990857
# Honda        10.874707
# Toyota       10.360889
# Name: mileage, dtype: float64

# %%
#program 3
from sympy import symbols,Eq,solve
x,y=symbols('x y')

#Linear equations
equation1=Eq(x+y,2200)
equation2=Eq(1.5*x+4*y,5050)


#Solution to those equations
solution=solve((equation1,equation2),(x,y))
child_count=solution[x]
adult_count=solution[y]
print("Number of children attending the fair:",int(child_count))
print("Number of adults attending the fair:",int(adult_count))
# Out:
# Number of children attending the fair: 1500
# Number of adults attending the fair: 700

# %%
#question 4
import pandas as pd
data={
'SN':[1,2,3],
'Name':['Linus Torvalds','Tim Berners-Lee','Guido van Rossum'],
'Country':['Finland','England','Netherlands'],
'Contributions':['Linux Kernel','World Wide Web','Python'],
'Year':[1991,1990,1991]
}
df=pd.DataFrame(data)
df.to_csv('Four.csv', index=False)
print("csv file created successfully")
print(df.head())
# Out:
# csv file created successfully
#    SN              Name      Country   Contributions  Year
# 0   1    Linus Torvalds      Finland    Linux Kernel  1991
# 1   2   Tim Berners-Lee      England  World Wide Web  1990
# 2   3  Guido van Rossum  Netherlands          Python  1991

# %%
#question 5
import pandas as pd
data = [
[1, 4000, 10000, 21000, 35500, 12000, 18000, 15450, 185000],
[2, 2500, 12000, 25000, 35500, 21000, 22000, 12000, 201000],
[3, 5200, 11000, 28000, 35500, 18000, 25000, 13450, 206000],
[4, 4100, 12000, 23000, 35500, 21000, 21000, 11300, 200500],
[5, 5550, 10000, 24000, 35500, 18000, 19000, 17450, 194000],
[6, 7900, 10000, 21000, 35500, 22000, 22000, 19450, 220000],
[7, 9100, 12000, 23000, 35500, 21000, 21000, 20100, 230000],
[8, 3550, 10000, 25000, 35500, 23000, 24000, 25400, 240000],
[9, 7900, 10000, 21000, 35500, 24000, 22000, 27100, 240000],
[10, 3100, 12000, 23000, 35500, 21000, 21000, 35450, 270000],
[11, 8550, 10000, 21000, 35500, 23000, 24000, 36800, 260000],
[12, 2900, 10000, 23000, 35500, 24000, 22000, 49200, 290000]]
columns = ['month_number', 'facecream', 'facewash', 'toothpaste',
'bathingsoap', 'shampoo', 'moisturizer', 'total_units', 'total_profit']
df = pd.DataFrame(data, columns=columns)
df.to_csv('five.csv', index=False)
import matplotlib.pyplot as plt
# Load the data from the CSV file
data = pd.read_csv('five.csv')
# Scatter plot for toothpaste sales data of each month
plt.figure(figsize=(8, 6))
plt.scatter(data['month_number'], data['toothpaste'], color='blue')
plt.title('Toothpaste Sales Data')
plt.xlabel('Month')
plt.ylabel('Toothpaste Sales')
plt.xticks(range(1, 13))
plt.grid(True)
plt.show()
plt.figure(figsize=(8, 6))
plt.bar(data['month_number'], data['facecream'], width=0.4,
label='Face Cream', align='center', alpha=0.7)
plt.bar(data['month_number'] + 0.4, data['facewash'], width=0.4,
label='Face Wash', align='center', alpha=0.7)
plt.title('Face Cream and Face Wash Sales Data')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul',
'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend()
plt.grid(True)
plt.show()
last_year_data = data[data['month_number'] >= 1] # Assuming the

total_sales = last_year_data[['facecream', 'facewash', 'toothpaste',
'bathingsoap', 'shampoo', 'moisturizer']].sum()
# Pie chart for total sale data
labels = total_sales.index
sizes = total_sales.values
plt.figure(figsize=(8, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Total Sale Data for Last Year')
plt.show()

# %%
#question 6
import pandas as pd


import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.tree import export_text


# Create a DataFrame with the given dataset
data = {
'House Furniture': ['No', 'Yes', 'No', 'No', 'Yes'],
'No. of Rooms': [3, 3, 4, 3, 4],
'New Kitchen': ['Yes', 'No', 'Yes', 'No', 'No'],
'Acceptable': ['Yes', 'No', 'Yes', 'No', 'Yes']
}
df = pd.DataFrame(data)

# Mapping categorical features to numerical values
df['House Furniture'] = df['House Furniture'].map({'No': 0, 'Yes': 1})
df['New Kitchen'] = df['New Kitchen'].map({'No': 0, 'Yes': 1})
df['Acceptable'] = df['Acceptable'].map({'No': 0, 'Yes': 1})


# Split the data into features (X) and target (y)
X = df.drop('Acceptable', axis=1)
y = df['Acceptable']


# Create and fit a decision tree classifier
clf = DecisionTreeClassifier()
clf.fit(X, y)

# Print the decision tree rules
tree_rules = export_text(clf, feature_names=list(X.columns))
print("Decision Tree Rules:")
print(tree_rules)

# Given dataset
labels = df['Acceptable']
def calculate_entropy(labels):
    unique_labels, label_counts = np.unique(labels,return_counts=True)
    probabilities = label_counts / len(labels)
    entropy = -np.sum(probabilities * np.log2(probabilities + 1e-10)) #Added a small epsilon to avoid log(0)
    return entropy
entropy = calculate_entropy(labels)
print("Entropy:", entropy)
model = DecisionTreeClassifier(criterion='entropy')


# Function to calculate information gain for each feature
def calculate_information_gain(X, y, feature):
    X_train, X_test, y_train, y_test = train_test_split(X[[feature]], y, test_size=0.2, random_state=42)
    model = DecisionTreeClassifier(criterion='entropy', random_state=42)
    model.fit(X_train, y_train)
    information_gain = model.tree_.impurity[0] - model.tree_.impurity[1]
    return information_gain

# Display information gain for each feature
print("Information Gain for each feature:")
for feature in X.columns:
    information_gain = calculate_information_gain(X, y, feature)
    print(f"{feature}: {information_gain:.4f}")
# Out:
# Decision Tree Rules:
# |--- New Kitchen <= 0.50
# |   |--- No. of Rooms <= 3.50
# |   |   |--- class: 0
# |   |--- No. of Rooms >  3.50
# |   |   |--- class: 1
# |--- New Kitchen >  0.50
# |   |--- class: 1
#
# Entropy: 0.9709505941661296
# Information Gain for each feature:
# House Furniture: -0.1070
# No. of Rooms: -0.1887
# New Kitchen: -0.1887

# %%
# question 
import numpy as np
from sklearn.ensemble import RandomForestClassifier
import pandas as pd

# Given dataset
data = {
    'Age': [30, 40, 25, 35, 28],
    'Gender': ['Female', 'Male', 'Male', 'Male', 'Female'],
    'Education': ['Graduate', 'Diploma', 'Post-Graduate', 'Diploma', 'Graduate'],
    'Industry': ['IT', 'Manufacturing', 'Finance', 'Manufacturing', 'IT'],
    'Residence': ['Non-metro', 'Metro', 'Non-metro', 'Metro', 'Metro'],
    'Income': ['Below 4,00,000', 'More than 15,00,000', 'Between 4,00,000 - 15,00,000', 
               'Between 4,00,000 - 15,00,000', 'Below 4,00,000']
}
df = pd.DataFrame(data)
print(df)

# Convert categorical variables to numerical values
df['Gender'] = df['Gender'].map({'Male': 0, 'Female': 1})
df['Education'] = df['Education'].map({'Diploma': 0, 'Graduate': 1, 'Post-Graduate': 2})
df['Industry'] = df['Industry'].astype('category').cat.codes
df['Residence'] = df['Residence'].map({'Metro': 0, 'Non-metro': 1})
df['Income'] = df['Income'].astype('category').cat.codes

# Features and target variable
X = df[['Age', 'Gender', 'Education', 'Industry', 'Residence']]
y = df['Income']

# Train the Random Forest Classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X, y)

# Make predictions for the given individual traits
new_data = np.array([[35, 0, 0, 1, 0]])  # Age: 35, Gender: Male, Education: Diploma, Industry: Manufacturing, Residence: Metro
prediction = clf.predict(new_data)

# Map the predicted value back to the original income category
category_mapping = {
    0: 'Below 4,00,000',
    1: 'Between 4,00,000 - 15,00,000',
    2: 'More than 15,00,000'
}

# Map the predicted category to the original income category
predicted_income_original = category_mapping[prediction[0]]
print(f"The predicted original income category is: {predicted_income_original}")
# Out:
#    Age  Gender      Education       Industry  Residence  \
# 0   30  Female       Graduate             IT  Non-metro
# 1   40    Male        Diploma  Manufacturing      Metro
# 2   25    Male  Post-Graduate        Finance  Non-metro
# 3   35    Male        Diploma  Manufacturing      Metro
# 4   28  Female       Graduate             IT      Metro
#
#                          Income
# 0                Below 4,00,000
# 1           More than 15,00,000
# 2  Between 4,00,000 - 15,00,000
# 3  Between 4,00,000 - 15,00,000
# 4                Below 4,00,000
# The predicted original income category is: Between 4,00,000 - 15,00,000
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
#question 8
from sklearn import datasets
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn import metrics

# Load the Iris dataset
iris = datasets.load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Extracting sepal length and petal length
sepal_length = iris_df['sepal length (cm)'].values
petal_length = iris_df['petal length (cm)'].values

# Creating feature matrix X
X = np.array(list(zip(sepal_length, petal_length)))

# Using the Elbow method to find the optimal number of clusters
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss, marker='o')
plt.title('Elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# Applying KMeans with the chosen number of clusters (3 in this case)
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(X)
y = kmeans.predict(X)

# Visualizing the clusters
plt.scatter(sepal_length, petal_length, c=kmeans.labels_)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', marker='X', s=200)
plt.title('K-Means Clustering with 3 Clusters')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')
plt.show()

# True labels for evaluation
true_labels = np.array([0]*50 + [1]*50 + [2]*50)

# Evaluate clustering performance
classification = metrics.classification_report(true_labels, y)
print('Classification Report:')
print(classification)
# Out:
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\acer\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        50
#            1       0.02      0.02      0.02        50
#            2       0.90      0.74      0.81        50
#
#     accuracy                           0.25       150
#    macro avg       0.31      0.25      0.28       150
# weighted avg       0.31      0.25      0.28       150

# %%
valid=['i','am','our']
invalid=['co','po','mt']

labels = [1] * len(valid) + [0] * len(invalid)
